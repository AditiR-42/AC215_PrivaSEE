# %% [markdown]
# ## Prototype of Scraping for Dataset 2

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random

# %%
# Base URL of the page (changing only the page number)
base_url = 'https://edit.tosdr.org/services?page='

# Create lists to hold the service names and ratings
services = []
ratings = []

# Loop through pages 1 to 415
for page_num in range(1, 416):
    # Construct the URL for the current page
    url = base_url + str(page_num)

    # Send a GET request to fetch the content of the page
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find the relevant table containing the services
    services_table = soup.find('table')

    # Extract the service names and ratings
    for row in services_table.find_all('tr'):
        cols = row.find_all('td')
        if len(cols) > 1:
            service_name = cols[0].get_text(strip=True)
            rating = cols[1].get_text(strip=True)
            services.append(service_name)
            ratings.append(rating)

    # Random sleep to avoid being blocked
    time.sleep(random.uniform(1, 10))

# Create a DataFrame from the lists
df = pd.DataFrame({
    'Service': services,
    'Rating': ratings
})

#save the df as a csv
df.to_csv('services_and_ratings.csv')

# Display the DataFrame
print(df)

# %%
print("hi")
# Out:
# hi

# %%
import requests
from bs4 import BeautifulSoup

# Base URL of the services page (changing only the page number)
base_url = 'https://edit.tosdr.org/services?page='
annotate_base_url = 'https://edit.tosdr.org'

# Create a list to hold the annotate URLs
annotate_urls = []

# Loop through pages 1 to 5 (adjust for page range you want to scrape)
for page_num in range(1, 2):
    # Construct the URL for the current page
    url = base_url + str(page_num)

    # Send a GET request to fetch the content of the page
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find the relevant table containing the services
    services_table = soup.find('table')

    # Extract the annotate URLs
    for row in services_table.find_all('tr'):
        annotate_button = row.find('a', string='Annotate')
        if annotate_button:
            annotate_link = annotate_button['href']
            full_annotate_url = annotate_base_url + annotate_link
            annotate_urls.append(full_annotate_url)

# Print the annotate URLs
for url in annotate_urls:
    print(url)
# Out:
# https://edit.tosdr.org/services/1570/annotate
# https://edit.tosdr.org/services/10569/annotate
# https://edit.tosdr.org/services/1352/annotate
# https://edit.tosdr.org/services/6718/annotate
# https://edit.tosdr.org/services/6369/annotate
# https://edit.tosdr.org/services/4855/annotate
# https://edit.tosdr.org/services/9591/annotate
# https://edit.tosdr.org/services/10348/annotate
# https://edit.tosdr.org/services/3154/annotate
# https://edit.tosdr.org/services/699/annotate
# https://edit.tosdr.org/services/11090/annotate
# https://edit.tosdr.org/services/9048/annotate
# https://edit.tosdr.org/services/2523/annotate
# https://edit.tosdr.org/services/6425/annotate
# https://edit.tosdr.org/services/9047/annotate
# https://edit.tosdr.org/services/1593/annotate
# https://edit.tosdr.org/services/7116/annotate
# https://edit.tosdr.org/services/5479/annotate
# https://edit.tosdr.org/services/3972/annotate
# https://edit.tosdr.org/services/1507/annotate
# https://edit.tosdr.org/services/3386/annotate
# https://edit.tosdr.org/services/9014/annotate
# https://edit.tosdr.org/services/4666/annotate
# https://edit.tosdr.org/services/1740/annotate
# https://edit.tosdr.org/services/11223/annotate

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL for the AliExpress annotate page
annotate_url = 'https://edit.tosdr.org/services/1570/annotate'

# Send a GET request to fetch the content of the page
response = requests.get(annotate_url)
soup = BeautifulSoup(response.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <!-- Facebook Open Graph data -->
# <meta content="Terms of Service; Didn't Read - Phoenix" property="og:title">
# <meta content="website" property="og:type">
# <meta content="https://edit.tosdr.org/users/sign_in" property="og:url">
# <meta content="https://edit.tosdr.org/assets/logo-a7911331e22c7441f84e711d897db7c8cb39e12fd01feaffdf11b7f711e85429.png" property="og:image"/>
# <meta content="I have read and understood the terms of service is the biggest lie on the Internet. We aim to fix that." property="og:description"/>
# <meta content="Terms of Service; Didn't Read - Phoenix" property="og:site_name"/>
# <!-- Twitter Card data -->
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@tosdr" name="twitter:site"/>
# <meta content="Terms of Service; Didn't Read - Phoenix" name="twitter:title"/>
# <meta content="I have read and understood the terms of service is the biggest lie on the Internet. We aim to fix that." name="twitter:description"/>
# <meta content="@tosdr" name="twitter:creator"/>
# <meta content="https://edit.tosdr.org/assets/logo-a7911331e22c7441f84e711d897db7c8cb39e12fd01feaffdf11b7f711e85429.png" name="twitter:image:src"/>
# <link href="/assets/favicon-20b5c217fa439e0558be39c4e46770b4cfa2a4e2c7c8a485a12f65d57cefacc2.ico" rel="shortcut icon" type="image/x-icon"/>
# <title>Terms Of Service; Didn't Read</title>
# <meta content="authenticity_token" name="csrf-param">
# <meta content="VaBz5kHM/vRE1czhtNwLGYw1CsyoT4Q8n/tk3kZrs0S7s87/LgNapcLNT7MWfjEODO06TH7xlwkUpek0rLuSJw==" name="csrf-token">
# <meta content="/cable" name="action-cable-url">
# <link href="/assets/application-d3094944bf2be25893ba2277cafeee1688b1b84d0c8ad04cc0580c6c52c24b0d.css" media="all" rel="stylesheet"/>
# </meta></meta></meta></meta></meta></meta></head>
# <body class="sessions new">
# <div class="navbar-tosdr navbar-fixed-top">
# <!-- Left Navigation -->
# <div class="navbar-tosdr-left">
# <!-- Logo -->
# <a class="navbar-tosdr-brand" href="/">
# <div class="navbar-tosdr-title">
# <img src="/assets/favicon-20b5c217fa439e0558be39c4e46770b4cfa2a4e2c7c8a485a12f65d57cefacc2.ico"/>
# <strong>ToS;</strong>DR
#       </div>
# </a>
# </div>
# <!-- Right Navigation -->
# <div class="navbar-tosdr-right hidden-xs hidden-sm">
# <!-- Links -->
# <div class="navbar-tosdr-group">
# <div class="navbar-tosdr-item">
# <!-- todo make the data toggle when user is logged in -->
# <div class="dropdown">
# <a class="navbar-tosdr-item navbar-tosdr-link" href="/about">About</a>
# <a class="navbar-tosdr-item navbar-tosdr-link dropdown-toggle" href="/users/sign_in" id="navbar-tosdr-menu">Login</a>
# <a class="btn btn-primary btn-sm" href="/users/sign_up">Sign up to contribute</a>
# </div>
# </div>
# </div>
# </div>
# <!-- Dropdown list appearing on mobile only -->
# <div class="navbar-tosdr-item hidden-md hidden-lg">
# <div class="dropdown">
# <i class="fa fa-bars dropdown-toggle" data-toggle="dropdown"></i>
# <ul class="dropdown-menu dropdown-menu-right navbar-tosdr-dropdown-menu">
# <li><a class="navbar-tosdr-item navbar-tosdr-link" href="/about">About</a></li>
# <li><a class="navbar-tosdr-item navbar-tosdr-link dropdown-toggle" href="/users/sign_in" id="navbar-tosdr-menu">Login</a></li>
# <li><a class="navbar-tosdr-item navbar-tosdr-link dropdown-toggle" href="/users/sign_up">Sign up</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="alert alert-warning alert-dismissible" role="alert">
# <button aria-label="Close" class="close" data-dismiss="alert" type="button"><span aria-hidden="true">×</span></button>
#    You need to sign in or sign up before continuing.
#  </div>
# <div class="container">
# <div class="container mwd">
# <div class="row">
# <h2>Log in</h2>
# <form accept-charset="UTF-8" action="/users/sign_in" class="simple_form new_user" id="new_user" method="post" novalidate="novalidate"><input name="authenticity_token" type="hidden" value="pUn3yV7ZNOVI40MD68hl6r0Aeevw3Kbh2h61c/8PFCueVLBYuroGR8MwwWg1HJZ3X1u196LNii4B6vxFSWsRTw=="/>
# <div class="form-inputs">
# <div class="form-group email optional user_email"><label class="control-label email optional" for="user_email">Email</label><input autofocus="autofocus" class="form-control string email optional" id="user_email" name="user[email]" type="email" value=""/></div>
# <div class="form-group password optional user_password"><label class="control-label password optional" for="user_password">Password</label><input class="form-control password optional" id="user_password" name="user[password]" type="password"/></div>
# <div class="form-group boolean optional user_remember_me"><div class="checkbox"><input name="user[remember_me]" type="hidden" value="0"/><label class="boolean optional" for="user_remember_me"><input class="boolean optional" id="user_remember_me" name="user[remember_me]" type="checkbox" value="1"/>Remember me</label></div></div>
# </div>
# <div class="form-actions">
# <input class="btn btn-default" data-disable-with="Log in" name="commit" type="submit" value="Log in"/>
# </div>
# </form>
# <a href="/users/sign_up">Sign up</a><br/>
# <a href="/users/password/new">Forgot your password?</a><br/>
# <a href="/users/confirmation/new">Didn't receive confirmation instructions?</a><br/>
# </div>
# </div>
# </div>
# <footer class="footer">
# <div class="footer-links hidden-xs">
# <a href="https://github.com/tosdr/phoenix">GitHub</a>
# <a href="https://twitter.com/tosdr">Twitter</a>
# <a href="https://github.com/tosdr/phoenix/wiki/API">API</a>
# </div>
# <div class="footer-links hidden-xs">
# <a href="/about">About</a>
# <a href="/about#contact">Contact</a>
# <a href="https://blog.tosdr.org">Blog</a>
# <a href="https://opencollective.com/tosdr">Donate</a>
# <a href="/about#tos">Terms of Service</a>
# <a href="https://github.com/tosdr/edit.tosdr.org">Version: Development</a>
# </div>
# <!-- Mobile Footer -->
# <div class="footer-links footer-mobile hidden-sm hidden-md hidden-lg">
# <a class="fa fa-github fa-lg" href="#"></a>
# <a class="fa fa-twitter fa-lg" href="#"></a>
# <a href="https://github.com/tosdr/phoenix/wiki/API">API</a>
# <a href="mailto:team at tosdr org">Contact</a>
# <a href="https://blog.tosdr.org">Blog</a>
# <a href="https://opencollective.com/tosdr">Donate</a>
# <a href="/about#tos">ToS</a>
# </div>
# </footer>
# <script src="/assets/application-56dfc40fe1aa503e5c11aba1b942f4404af924bf56d5c786ddd9dea658d05bba.js"></script>
# <script src="https://rksyl9kf1wtg.statuspage.io/embed/script.js"></script>
# <script src="https://tosdr.atlassian.net/s/d41d8cd98f00b204e9800998ecf8427e-T/sb53l8/b/24/bc54840da492f9ca037209037ef0522a/_/download/batch/com.atlassian.jira.collector.plugin.jira-issue-collector-plugin:issuecollector/com.atlassian.jira.collector.plugin.jira-issue-collector-plugin:issuecollector.js?locale=en-US&amp;collectorId=a3477685" type="text/javascript"></script>
# </body>
# </html>

# %%
import requests
from bs4 import BeautifulSoup

# URL for the AliExpress annotate page
annotate_url = 'https://edit.tosdr.org/services/1570/annotate'

# Send a GET request to fetch the content of the page
response = requests.get(annotate_url)
soup = BeautifulSoup(response.content, 'html.parser')

# Inspect the structure of the page by printing all 'div' elements
for div in soup.find_all('div'):
    print(div.prettify())
# Out:
# <div class="navbar-tosdr navbar-fixed-top">
#  <!-- Left Navigation -->
#  <div class="navbar-tosdr-left">
#   <!-- Logo -->
#   <a class="navbar-tosdr-brand" href="/">
#    <div class="navbar-tosdr-title">
#     <img src="/assets/favicon-20b5c217fa439e0558be39c4e46770b4cfa2a4e2c7c8a485a12f65d57cefacc2.ico"/>
#     <strong>
#      ToS;
#     </strong>
#     DR
#    </div>
#   </a>
#  </div>
#  <!-- Right Navigation -->
#  <div class="navbar-tosdr-right hidden-xs hidden-sm">
#   <!-- Links -->
#   <div class="navbar-tosdr-group">
#    <div class="navbar-tosdr-item">
#     <!-- todo make the data toggle when user is logged in -->
#     <div class="dropdown">
#      <a class="navbar-tosdr-item navbar-tosdr-link" href="/about">
#       About
#      </a>
#      <a class="navbar-tosdr-item navbar-tosdr-link dropdown-toggle" href="/users/sign_in" id="navbar-tosdr-menu">
#       Login
#      </a>
#      <a class="btn btn-primary btn-sm" href="/users/sign_up">
#       Sign up to contribute
#      </a>
#     </div>
#    </div>
#   </div>
#  </div>
#  <!-- Dropdown list appearing on mobile only -->
#  <div class="navbar-tosdr-item hidden-md hidden-lg">
#   <div class="dropdown">
#    <i class="fa fa-bars dropdown-toggle" data-toggle="dropdown">
#    </i>
#    <ul class="dropdown-menu dropdown-menu-right navbar-tosdr-dropdown-menu">
#     <li>
#      <a class="navbar-tosdr-item navbar-tosdr-link" href="/about">
#       About
#      </a>
#     </li>
#     <li>
#      <a class="navbar-tosdr-item navbar-tosdr-link dropdown-toggle" href="/users/sign_in" id="navbar-tosdr-menu">
#       Login
#      </a>
#     </li>
#     <li>
#      <a class="navbar-tosdr-item navbar-tosdr-link dropdown-toggle" href="/users/sign_up">
#       Sign up
#      </a>
#     </li>
#    </ul>
#   </div>
#  </div>
# </div>
#
# <div class="navbar-tosdr-left">
#  <!-- Logo -->
#  <a class="navbar-tosdr-brand" href="/">
#   <div class="navbar-tosdr-title">
#    <img src="/assets/favicon-20b5c217fa439e0558be39c4e46770b4cfa2a4e2c7c8a485a12f65d57cefacc2.ico"/>
#    <strong>
#     ToS;
#    </strong>
#    DR
#   </div>
#  </a>
# </div>
#
# <div class="navbar-tosdr-title">
#  <img src="/assets/favicon-20b5c217fa439e0558be39c4e46770b4cfa2a4e2c7c8a485a12f65d57cefacc2.ico"/>
#  <strong>
#   ToS;
#  </strong>
#  DR
# </div>
#
# <div class="navbar-tosdr-right hidden-xs hidden-sm">
#  <!-- Links -->
#  <div class="navbar-tosdr-group">
#   <div class="navbar-tosdr-item">
#    <!-- todo make the data toggle when user is logged in -->
#    <div class="dropdown">
#     <a class="navbar-tosdr-item navbar-tosdr-link" href="/about">
#      About
#     </a>
#     <a class="navbar-tosdr-item navbar-tosdr-link dropdown-toggle" href="/users/sign_in" id="navbar-tosdr-menu">
#      Login
#     </a>
#     <a class="btn btn-primary btn-sm" href="/users/sign_up">
#      Sign up to contribute
#     </a>
#    </div>
#   </div>
#  </div>
# </div>
#
# <div class="navbar-tosdr-group">
#  <div class="navbar-tosdr-item">
#   <!-- todo make the data toggle when user is logged in -->
#   <div class="dropdown">
#    <a class="navbar-tosdr-item navbar-tosdr-link" href="/about">
#     About
#    </a>
#    <a class="navbar-tosdr-item navbar-tosdr-link dropdown-toggle" href="/users/sign_in" id="navbar-tosdr-menu">
#     Login
#    </a>
#    <a class="btn btn-primary btn-sm" href="/users/sign_up">
#     Sign up to contribute
#    </a>
#   </div>
#  </div>
# </div>
#
# <div class="navbar-tosdr-item">
#  <!-- todo make the data toggle when user is logged in -->
#  <div class="dropdown">
#   <a class="navbar-tosdr-item navbar-tosdr-link" href="/about">
#    About
#   </a>
#   <a class="navbar-tosdr-item navbar-tosdr-link dropdown-toggle" href="/users/sign_in" id="navbar-tosdr-menu">
#    Login
#   </a>
#   <a class="btn btn-primary btn-sm" href="/users/sign_up">
#    Sign up to contribute
#   </a>
#  </div>
# </div>
#
# <div class="dropdown">
#  <a class="navbar-tosdr-item navbar-tosdr-link" href="/about">
#   About
#  </a>
#  <a class="navbar-tosdr-item navbar-tosdr-link dropdown-toggle" href="/users/sign_in" id="navbar-tosdr-menu">
#   Login
#  </a>
#  <a class="btn btn-primary btn-sm" href="/users/sign_up">
#   Sign up to contribute
#  </a>
# </div>
#
# <div class="navbar-tosdr-item hidden-md hidden-lg">
#  <div class="dropdown">
#   <i class="fa fa-bars dropdown-toggle" data-toggle="dropdown">
#   </i>
#   <ul class="dropdown-menu dropdown-menu-right navbar-tosdr-dropdown-menu">
#    <li>
#     <a class="navbar-tosdr-item navbar-tosdr-link" href="/about">
#      About
#     </a>
#    </li>
#    <li>
#     <a class="navbar-tosdr-item navbar-tosdr-link dropdown-toggle" href="/users/sign_in" id="navbar-tosdr-menu">
#      Login
#     </a>
#    </li>
#    <li>
#     <a class="navbar-tosdr-item navbar-tosdr-link dropdown-toggle" href="/users/sign_up">
#      Sign up
#     </a>
#    </li>
#   </ul>
#  </div>
# </div>
#
# <div class="dropdown">
#  <i class="fa fa-bars dropdown-toggle" data-toggle="dropdown">
#  </i>
#  <ul class="dropdown-menu dropdown-menu-right navbar-tosdr-dropdown-menu">
#   <li>
#    <a class="navbar-tosdr-item navbar-tosdr-link" href="/about">
#     About
#    </a>
#   </li>
#   <li>
#    <a class="navbar-tosdr-item navbar-tosdr-link dropdown-toggle" href="/users/sign_in" id="navbar-tosdr-menu">
#     Login
#    </a>
#   </li>
#   <li>
#    <a class="navbar-tosdr-item navbar-tosdr-link dropdown-toggle" href="/users/sign_up">
#     Sign up
#    </a>
#   </li>
#  </ul>
# </div>
#
# <div class="alert alert-warning alert-dismissible" role="alert">
#  <button aria-label="Close" class="close" data-dismiss="alert" type="button">
#   <span aria-hidden="true">
#    ×
#   </span>
#  </button>
#  You need to sign in or sign up before continuing.
# </div>
#
# <div class="container">
#  <div class="container mwd">
#   <div class="row">
#    <h2>
#     Log in
#    </h2>
#    <form accept-charset="UTF-8" action="/users/sign_in" class="simple_form new_user" id="new_user" method="post" novalidate="novalidate">
#     <input name="authenticity_token" type="hidden" value="Jcu17rxrJbLAXCAL7vJOGUhojiJg3ntXUCwFOYZSbsV7Dhcjb0zqPl2Gh4fBc8sfhjK1apFzMuAmyiWcozE06Q=="/>
#     <div class="form-inputs">
#      <div class="form-group email optional user_email">
#       <label class="control-label email optional" for="user_email">
#        Email
#       </label>
#       <input autofocus="autofocus" class="form-control string email optional" id="user_email" name="user[email]" type="email" value=""/>
#      </div>
#      <div class="form-group password optional user_password">
#       <label class="control-label password optional" for="user_password">
#        Password
#       </label>
#       <input class="form-control password optional" id="user_password" name="user[password]" type="password"/>
#      </div>
#      <div class="form-group boolean optional user_remember_me">
#       <div class="checkbox">
#        <input name="user[remember_me]" type="hidden" value="0"/>
#        <label class="boolean optional" for="user_remember_me">
#         <input class="boolean optional" id="user_remember_me" name="user[remember_me]" type="checkbox" value="1"/>
#         Remember me
#        </label>
#       </div>
#      </div>
#     </div>
#     <div class="form-actions">
#      <input class="btn btn-default" data-disable-with="Log in" name="commit" type="submit" value="Log in"/>
#     </div>
#    </form>
#    <a href="/users/sign_up">
#     Sign up
#    </a>
#    <br/>
#    <a href="/users/password/new">
#     Forgot your password?
#    </a>
#    <br/>
#    <a href="/users/confirmation/new">
#     Didn't receive confirmation instructions?
#    </a>
#    <br/>
#   </div>
#  </div>
# </div>
#
# <div class="container mwd">
#  <div class="row">
#   <h2>
#    Log in
#   </h2>
#   <form accept-charset="UTF-8" action="/users/sign_in" class="simple_form new_user" id="new_user" method="post" novalidate="novalidate">
#    <input name="authenticity_token" type="hidden" value="Jcu17rxrJbLAXCAL7vJOGUhojiJg3ntXUCwFOYZSbsV7Dhcjb0zqPl2Gh4fBc8sfhjK1apFzMuAmyiWcozE06Q=="/>
#    <div class="form-inputs">
#     <div class="form-group email optional user_email">
#      <label class="control-label email optional" for="user_email">
#       Email
#      </label>
#      <input autofocus="autofocus" class="form-control string email optional" id="user_email" name="user[email]" type="email" value=""/>
#     </div>
#     <div class="form-group password optional user_password">
#      <label class="control-label password optional" for="user_password">
#       Password
#      </label>
#      <input class="form-control password optional" id="user_password" name="user[password]" type="password"/>
#     </div>
#     <div class="form-group boolean optional user_remember_me">
#      <div class="checkbox">
#       <input name="user[remember_me]" type="hidden" value="0"/>
#       <label class="boolean optional" for="user_remember_me">
#        <input class="boolean optional" id="user_remember_me" name="user[remember_me]" type="checkbox" value="1"/>
#        Remember me
#       </label>
#      </div>
#     </div>
#    </div>
#    <div class="form-actions">
#     <input class="btn btn-default" data-disable-with="Log in" name="commit" type="submit" value="Log in"/>
#    </div>
#   </form>
#   <a href="/users/sign_up">
#    Sign up
#   </a>
#   <br/>
#   <a href="/users/password/new">
#    Forgot your password?
#   </a>
#   <br/>
#   <a href="/users/confirmation/new">
#    Didn't receive confirmation instructions?
#   </a>
#   <br/>
#  </div>
# </div>
#
# <div class="row">
#  <h2>
#   Log in
#  </h2>
#  <form accept-charset="UTF-8" action="/users/sign_in" class="simple_form new_user" id="new_user" method="post" novalidate="novalidate">
#   <input name="authenticity_token" type="hidden" value="Jcu17rxrJbLAXCAL7vJOGUhojiJg3ntXUCwFOYZSbsV7Dhcjb0zqPl2Gh4fBc8sfhjK1apFzMuAmyiWcozE06Q=="/>
#   <div class="form-inputs">
#    <div class="form-group email optional user_email">
#     <label class="control-label email optional" for="user_email">
#      Email
#     </label>
#     <input autofocus="autofocus" class="form-control string email optional" id="user_email" name="user[email]" type="email" value=""/>
#    </div>
#    <div class="form-group password optional user_password">
#     <label class="control-label password optional" for="user_password">
#      Password
#     </label>
#     <input class="form-control password optional" id="user_password" name="user[password]" type="password"/>
#    </div>
#    <div class="form-group boolean optional user_remember_me">
#     <div class="checkbox">
#      <input name="user[remember_me]" type="hidden" value="0"/>
#      <label class="boolean optional" for="user_remember_me">
#       <input class="boolean optional" id="user_remember_me" name="user[remember_me]" type="checkbox" value="1"/>
#       Remember me
#      </label>
#     </div>
#    </div>
#   </div>
#   <div class="form-actions">
#    <input class="btn btn-default" data-disable-with="Log in" name="commit" type="submit" value="Log in"/>
#   </div>
#  </form>
#  <a href="/users/sign_up">
#   Sign up
#  </a>
#  <br/>
#  <a href="/users/password/new">
#   Forgot your password?
#  </a>
#  <br/>
#  <a href="/users/confirmation/new">
#   Didn't receive confirmation instructions?
#  </a>
#  <br/>
# </div>
#
# <div class="form-inputs">
#  <div class="form-group email optional user_email">
#   <label class="control-label email optional" for="user_email">
#    Email
#   </label>
#   <input autofocus="autofocus" class="form-control string email optional" id="user_email" name="user[email]" type="email" value=""/>
#  </div>
#  <div class="form-group password optional user_password">
#   <label class="control-label password optional" for="user_password">
#    Password
#   </label>
#   <input class="form-control password optional" id="user_password" name="user[password]" type="password"/>
#  </div>
#  <div class="form-group boolean optional user_remember_me">
#   <div class="checkbox">
#    <input name="user[remember_me]" type="hidden" value="0"/>
#    <label class="boolean optional" for="user_remember_me">
#     <input class="boolean optional" id="user_remember_me" name="user[remember_me]" type="checkbox" value="1"/>
#     Remember me
#    </label>
#   </div>
#  </div>
# </div>
#
# <div class="form-group email optional user_email">
#  <label class="control-label email optional" for="user_email">
#   Email
#  </label>
#  <input autofocus="autofocus" class="form-control string email optional" id="user_email" name="user[email]" type="email" value=""/>
# </div>
#
# <div class="form-group password optional user_password">
#  <label class="control-label password optional" for="user_password">
#   Password
#  </label>
#  <input class="form-control password optional" id="user_password" name="user[password]" type="password"/>
# </div>
#
# <div class="form-group boolean optional user_remember_me">
#  <div class="checkbox">
#   <input name="user[remember_me]" type="hidden" value="0"/>
#   <label class="boolean optional" for="user_remember_me">
#    <input class="boolean optional" id="user_remember_me" name="user[remember_me]" type="checkbox" value="1"/>
#    Remember me
#   </label>
#  </div>
# </div>
#
# <div class="checkbox">
#  <input name="user[remember_me]" type="hidden" value="0"/>
#  <label class="boolean optional" for="user_remember_me">
#   <input class="boolean optional" id="user_remember_me" name="user[remember_me]" type="checkbox" value="1"/>
#   Remember me
#  </label>
# </div>
#
# <div class="form-actions">
#  <input class="btn btn-default" data-disable-with="Log in" name="commit" type="submit" value="Log in"/>
# </div>
#
# <div class="footer-links hidden-xs">
#  <a href="https://github.com/tosdr/phoenix">
#   GitHub
#  </a>
#  <a href="https://twitter.com/tosdr">
#   Twitter
#  </a>
#  <a href="https://github.com/tosdr/phoenix/wiki/API">
#   API
#  </a>
# </div>
#
# <div class="footer-links hidden-xs">
#  <a href="/about">
#   About
#  </a>
#  <a href="/about#contact">
#   Contact
#  </a>
#  <a href="https://blog.tosdr.org">
#   Blog
#  </a>
#  <a href="https://opencollective.com/tosdr">
#   Donate
#  </a>
#  <a href="/about#tos">
#   Terms of Service
#  </a>
#  <a href="https://github.com/tosdr/edit.tosdr.org">
#   Version: Development
#  </a>
# </div>
#
# <div class="footer-links footer-mobile hidden-sm hidden-md hidden-lg">
#  <a class="fa fa-github fa-lg" href="#">
#  </a>
#  <a class="fa fa-twitter fa-lg" href="#">
#  </a>
#  <a href="https://github.com/tosdr/phoenix/wiki/API">
#   API
#  </a>
#  <a href="mailto:team at tosdr org">
#   Contact
#  </a>
#  <a href="https://blog.tosdr.org">
#   Blog
#  </a>
#  <a href="https://opencollective.com/tosdr">
#   Donate
#  </a>
#  <a href="/about#tos">
#   ToS
#  </a>
# </div>

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from bs4 import BeautifulSoup
import pandas as pd
import time

# Path to your ChromeDriver
driver_path = '/path/to/chromedriver'

# Set up the ChromeDriver service
service = Service(driver_path)
driver = webdriver.Chrome(service=service)

# URL for the AliExpress annotate page
annotate_url = 'https://edit.tosdr.org/services/1570/annotate'

# Navigate to the page
driver.get(annotate_url)

# Let the page load
time.sleep(3)

# Get page source after JavaScript has rendered
page_source = driver.page_source

# Parse the page with BeautifulSoup
soup = BeautifulSoup(page_source, 'html.parser')

# Close the browser
driver.quit()

# Now, let's try to find the highlighted text and annotations
highlighted_texts = []
annotations = []

for annotation_item in soup.find_all('div', class_='annotation'):
    highlighted = annotation_item.find('mark')  # Try 'mark' or another tag for highlighted text
    if highlighted:
        highlighted_texts.append(highlighted.get_text(strip=True))

    annotation_text = annotation_item.find('div', class_='annotation-text').get_text(strip=True)
    annotations.append(annotation_text)

# Create a DataFrame to hold the results
df = pd.DataFrame({
    'Highlighted Text': highlighted_texts,
    'Annotation': annotations
})

# Display the DataFrame
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/common/driver_finder.py:64, in DriverFinder._binary_paths(self)
#      63 if not Path(path).is_file():
# ---> 64     raise ValueError(f"The path is not a valid file: {path}")
#      65 self._paths["driver_path"] = path
#
# ValueError: The path is not a valid file: /path/to/chromedriver
#
# The above exception was the direct cause of the following exception:
#
# NoSuchDriverException                     Traceback (most recent call last)
# Cell In[10], line 12
#      10 # Set up the ChromeDriver service
#      11 service = Service(driver_path)
# ---> 12 driver = webdriver.Chrome(service=service)
#      14 # URL for the AliExpress annotate page
#      15 annotate_url = 'https://edit.tosdr.org/services/1570/annotate'
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/chrome/webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     browser_name=DesiredCapabilities.CHROME["browserName"],
#      47     vendor_prefix="goog",
#      48     options=options,
#      49     service=service,
#      50     keep_alive=keep_alive,
#      51 )
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/chromium/webdriver.py:50, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      47 self.service = service
#      49 finder = DriverFinder(self.service, options)
# ---> 50 if finder.get_browser_path():
#      51     options.binary_location = finder.get_browser_path()
#      52     options.browser_version = None
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/common/driver_finder.py:47, in DriverFinder.get_browser_path(self)
#      46 def get_browser_path(self) -> str:
# ---> 47     return self._binary_paths()["browser_path"]
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/common/driver_finder.py:78, in DriverFinder._binary_paths(self)
#      76 except Exception as err:
#      77     msg = f"Unable to obtain driver for {browser}"
# ---> 78     raise NoSuchDriverException(msg) from err
#      79 return self._paths
#
# NoSuchDriverException: Message: Unable to obtain driver for chrome; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors/driver_location

# %%
#trying this a different way: going through cases.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from bs4 import BeautifulSoup
import time

# Path to your ChromeDriver
driver_path = '/path/to/chromedriver'

# Set up the ChromeDriver service
service = Service(driver_path)
driver = webdriver.Chrome(service=service)

# URL for the page to scrape
url = 'https://edit.tosdr.org/cases'

# Navigate to the page
driver.get(url)

# Let the page load (adjust the time if needed)
time.sleep(3)

# Get the page source after JavaScript has rendered
page_source = driver.page_source

# Parse the page with BeautifulSoup
soup = BeautifulSoup(page_source, 'html.parser')

# Close the browser
driver.quit()

# Find and print the titles under the "Title" column
for row in soup.find_all('tr'):
    cols = row.find_all('td')
    if len(cols) > 0:
        title = cols[0].get_text(strip=True)
        print(title)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/common/driver_finder.py:64, in DriverFinder._binary_paths(self)
#      63 if not Path(path).is_file():
# ---> 64     raise ValueError(f"The path is not a valid file: {path}")
#      65 self._paths["driver_path"] = path
#
# ValueError: The path is not a valid file: /path/to/chromedriver
#
# The above exception was the direct cause of the following exception:
#
# NoSuchDriverException                     Traceback (most recent call last)
# Cell In[24], line 11
#       9 # Set up the ChromeDriver service
#      10 service = Service(driver_path)
# ---> 11 driver = webdriver.Chrome(service=service)
#      13 # URL for the page to scrape
#      14 url = 'https://edit.tosdr.org/cases'
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/chrome/webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     browser_name=DesiredCapabilities.CHROME["browserName"],
#      47     vendor_prefix="goog",
#      48     options=options,
#      49     service=service,
#      50     keep_alive=keep_alive,
#      51 )
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/chromium/webdriver.py:50, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      47 self.service = service
#      49 finder = DriverFinder(self.service, options)
# ---> 50 if finder.get_browser_path():
#      51     options.binary_location = finder.get_browser_path()
#      52     options.browser_version = None
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/common/driver_finder.py:47, in DriverFinder.get_browser_path(self)
#      46 def get_browser_path(self) -> str:
# ---> 47     return self._binary_paths()["browser_path"]
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/common/driver_finder.py:78, in DriverFinder._binary_paths(self)
#      76 except Exception as err:
#      77     msg = f"Unable to obtain driver for {browser}"
# ---> 78     raise NoSuchDriverException(msg) from err
#      79 return self._paths
#
# NoSuchDriverException: Message: Unable to obtain driver for chrome; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors/driver_location

# %%
import asyncio
from playwright.async_api import async_playwright
import pandas as pd

# Global variable to store the DataFrame
df = None

# Async function to scrape the page using Playwright
async def scrape_page():
    global df
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        # Navigate to the page
        await page.goto('https://edit.tosdr.org/topics')

        # Wait for content to load
        await page.wait_for_selector('tr')

        # Extract the titles and links
        titles = await page.locator('tr td:nth-child(2) a').all_inner_texts()
        links = await page.locator('tr td:nth-child(2) a').evaluate_all('elements => elements.map(e => e.href)')

        # Create the DataFrame
        df = pd.DataFrame({'Title': titles, 'Link': links})

        # Close the browser
        await browser.close()

# Create and run the async function
await scrape_page()

# %%
#rename
df.rename(columns={'Title': 'Topic', 'Link': 'topic_link'}, inplace=True)

# Print the DataFrame
print(df)

# Save the DataFrame to a CSV file
df.to_csv('tosdr_topics.csv', index=False)
# Out:
#                                  Topic                        topic_link
# 0                            Ownership  https://edit.tosdr.org/topics/27
# 1                           Governance  https://edit.tosdr.org/topics/31
# 2                            Guarantee  https://edit.tosdr.org/topics/32
# 3   User Involvement in Changing Terms  https://edit.tosdr.org/topics/35
# 4                              Changes  https://edit.tosdr.org/topics/38
# 5                         Unclassified  https://edit.tosdr.org/topics/53
# 6      Jurisdiction and governing laws  https://edit.tosdr.org/topics/44
# 7             Notice of Changing Terms  https://edit.tosdr.org/topics/46
# 8            Suspension and Censorship  https://edit.tosdr.org/topics/47
# 9                   Business Transfers  https://edit.tosdr.org/topics/39
# 10                                Logs  https://edit.tosdr.org/topics/40
# 11                            Security  https://edit.tosdr.org/topics/50
# 12                            Payments  https://edit.tosdr.org/topics/54
# 13                             Content  https://edit.tosdr.org/topics/52
# 14                   Copyright License  https://edit.tosdr.org/topics/30
# 15                            Trackers  https://edit.tosdr.org/topics/25
# 16                       Personal Data  https://edit.tosdr.org/topics/41
# 17                        [Deprecated]  https://edit.tosdr.org/topics/55
# 18                           Anonymity  https://edit.tosdr.org/topics/26
# 19      Types of Information Collected  https://edit.tosdr.org/topics/56
# 20                         User Choice  https://edit.tosdr.org/topics/34
# 21                       Third Parties  https://edit.tosdr.org/topics/48
# 22          Right to Leave The Service  https://edit.tosdr.org/topics/45
# 23         Law and Government Requests  https://edit.tosdr.org/topics/28
# 24                         Advertising  https://edit.tosdr.org/topics/57
# 25                        Transparency  https://edit.tosdr.org/topics/36
# 26                             Waivers  https://edit.tosdr.org/topics/37
# 27                  Dispute Resolution  https://edit.tosdr.org/topics/42

# %%
df = pd.read_csv('tosdr_topics.csv')
df
# Out:
#                                  Topic                        topic_link
# 0                            Ownership  https://edit.tosdr.org/topics/27
# 1                           Governance  https://edit.tosdr.org/topics/31
# 2                            Guarantee  https://edit.tosdr.org/topics/32
# 3   User Involvement in Changing Terms  https://edit.tosdr.org/topics/35
# 4                              Changes  https://edit.tosdr.org/topics/38
# 5                         Unclassified  https://edit.tosdr.org/topics/53
# 6      Jurisdiction and governing laws  https://edit.tosdr.org/topics/44
# 7             Notice of Changing Terms  https://edit.tosdr.org/topics/46
# 8            Suspension and Censorship  https://edit.tosdr.org/topics/47
# 9                   Business Transfers  https://edit.tosdr.org/topics/39
# 10                                Logs  https://edit.tosdr.org/topics/40
# 11                            Security  https://edit.tosdr.org/topics/50
# 12                            Payments  https://edit.tosdr.org/topics/54
# 13                             Content  https://edit.tosdr.org/topics/52
# 14                   Copyright License  https://edit.tosdr.org/topics/30
# 15                            Trackers  https://edit.tosdr.org/topics/25
# 16                       Personal Data  https://edit.tosdr.org/topics/41
# 17                        [Deprecated]  https://edit.tosdr.org/topics/55
# 18                           Anonymity  https://edit.tosdr.org/topics/26
# 19      Types of Information Collected  https://edit.tosdr.org/topics/56
# 20                         User Choice  https://edit.tosdr.org/topics/34
# 21                       Third Parties  https://edit.tosdr.org/topics/48
# 22          Right to Leave The Service  https://edit.tosdr.org/topics/45
# 23         Law and Government Requests  https://edit.tosdr.org/topics/28
# 24                         Advertising  https://edit.tosdr.org/topics/57
# 25                        Transparency  https://edit.tosdr.org/topics/36
# 26                             Waivers  https://edit.tosdr.org/topics/37
# 27                  Dispute Resolution  https://edit.tosdr.org/topics/42

# %%
import asyncio
from playwright.async_api import async_playwright
import pandas as pd

# Async function to scrape cases for each topic
async def scrape_cases(topic, topic_link, page):
    await page.goto(topic_link)

    # Wait for the specific case list to load (targeting the specific div or section)
    await page.wait_for_selector('div.card-inline')

    # Extract the case titles and links (only within the specific section you're interested in)
    case_titles = await page.locator('div.card-inline td a').all_inner_texts()
    case_links = await page.locator('div.card-inline td a').evaluate_all('elements => elements.map(e => e.href)')

    # Return a list of cases, each associated with the topic
    cases = []
    for case_title, case_link in zip(case_titles, case_links):
        cases.append({
            'Topic': topic,
            'Topic Link': topic_link,
            'Case': case_title,
            'Case Link': case_link
        })
    return cases

# Async function to scrape the page using Playwright
async def scrape_page():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        # Navigate to the topics page
        await page.goto('https://edit.tosdr.org/topics')
        await page.wait_for_selector('tr')

        # Extract the topic titles and links
        topics = await page.locator('tr td:nth-child(2) a').all_inner_texts()
        topic_links = await page.locator('tr td:nth-child(2) a').evaluate_all('elements => elements.map(e => e.href)')

        all_cases = []
        # Loop over each topic and get cases
        for topic, topic_link in zip(topics, topic_links):
            cases = await scrape_cases(topic, topic_link, page)
            all_cases.extend(cases)

        await browser.close()

        # Convert the list of cases to a DataFrame
        df = pd.DataFrame(all_cases)
        return df

# In a Jupyter notebook, use await directly instead of asyncio.run
df = await scrape_page()

# Display the DataFrame
print(df)

# Save the DataFrame to a CSV file
df.to_csv('tosdr_topics_and_cases.csv', index=False)
# Out:
#                   Topic                        Topic Link  \
# 0             Ownership  https://edit.tosdr.org/topics/27
# 1             Ownership  https://edit.tosdr.org/topics/27
# 2             Ownership  https://edit.tosdr.org/topics/27
# 3             Ownership  https://edit.tosdr.org/topics/27
# 4             Ownership  https://edit.tosdr.org/topics/27
# ..                  ...                               ...
# 255        Transparency  https://edit.tosdr.org/topics/36
# 256        Transparency  https://edit.tosdr.org/topics/36
# 257  Dispute Resolution  https://edit.tosdr.org/topics/42
# 258  Dispute Resolution  https://edit.tosdr.org/topics/42
# 259  Dispute Resolution  https://edit.tosdr.org/topics/42
#
#                                                   Case  \
# 0           This service takes credit for your content
# 1    If you offer suggestions to the service, they ...
# 2               You maintain ownership of your content
# 3    This service can use your content for all thei...
# 4    The service disables software that you are not...
# ..                                                 ...
# 255  An audio version of the Terms of Service is pr...
# 256  Information is provided about what kind of inf...
# 257  You aren’t forced into binding arbitration in ...
# 258  You are forced into binding arbitration in cas...
# 259            You waive your right to a class action.
#
#                             Case Link
# 0    https://edit.tosdr.org/cases/179
# 1    https://edit.tosdr.org/cases/182
# 2    https://edit.tosdr.org/cases/183
# 3    https://edit.tosdr.org/cases/180
# 4    https://edit.tosdr.org/cases/330
# ..                                ...
# 255  https://edit.tosdr.org/cases/494
# 256  https://edit.tosdr.org/cases/228
# 257  https://edit.tosdr.org/cases/335
# 258  https://edit.tosdr.org/cases/339
# 259  https://edit.tosdr.org/cases/117
#
# [260 rows x 4 columns]

# %%
#save info on classification and weight for each Topic Link

# %%
df = pd.read_csv('tosdr_topics_and_cases.csv')
df
# Out:
#                   Topic                        Topic Link  \
# 0             Ownership  https://edit.tosdr.org/topics/27
# 1             Ownership  https://edit.tosdr.org/topics/27
# 2             Ownership  https://edit.tosdr.org/topics/27
# 3             Ownership  https://edit.tosdr.org/topics/27
# 4             Ownership  https://edit.tosdr.org/topics/27
# ..                  ...                               ...
# 255        Transparency  https://edit.tosdr.org/topics/36
# 256        Transparency  https://edit.tosdr.org/topics/36
# 257  Dispute Resolution  https://edit.tosdr.org/topics/42
# 258  Dispute Resolution  https://edit.tosdr.org/topics/42
# 259  Dispute Resolution  https://edit.tosdr.org/topics/42
#
#                                                   Case  \
# 0           This service takes credit for your content
# 1    If you offer suggestions to the service, they ...
# 2               You maintain ownership of your content
# 3    This service can use your content for all thei...
# 4    The service disables software that you are not...
# ..                                                 ...
# 255  An audio version of the Terms of Service is pr...
# 256  Information is provided about what kind of inf...
# 257  You aren’t forced into binding arbitration in ...
# 258  You are forced into binding arbitration in cas...
# 259            You waive your right to a class action.
#
#                             Case Link
# 0    https://edit.tosdr.org/cases/179
# 1    https://edit.tosdr.org/cases/182
# 2    https://edit.tosdr.org/cases/183
# 3    https://edit.tosdr.org/cases/180
# 4    https://edit.tosdr.org/cases/330
# ..                                ...
# 255  https://edit.tosdr.org/cases/494
# 256  https://edit.tosdr.org/cases/228
# 257  https://edit.tosdr.org/cases/335
# 258  https://edit.tosdr.org/cases/339
# 259  https://edit.tosdr.org/cases/117
#
# [260 rows x 4 columns]

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random

# Function to scrape classification and weight from the case link
def scrape_case_details(case_link):
    response = requests.get(case_link)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Extract Classification and Weight with fallback
    classification_tag = soup.find('p', string=lambda text: 'Classification' in text if text else False)
    weight_tag = soup.find('p', string=lambda text: 'Weight' in text if text else False)

    # Check for colon before splitting to avoid IndexError
    classification = classification_tag.get_text().split(":")[1].strip() if classification_tag and ":" in classification_tag.get_text() else None
    weight = weight_tag.get_text().split(":")[1].strip() if weight_tag and ":" in weight_tag.get_text() else None

    return classification, weight

# Main function to loop through case links
def scrape_page(df):
    all_data = []
    for _, row in df.iterrows():
        case_link = row['Case Link']
        classification, weight = scrape_case_details(case_link)

        # Append the results to the list
        all_data.append({
            'Case Link': case_link,
            'Classification': classification,
            'Weight': weight
        })

        # Add a random sleep between 1 and 3 seconds
        time.sleep(random.uniform(1, 3))

    return pd.DataFrame(all_data)

# Load your initial DataFrame
df = pd.read_csv('tosdr_topics_and_cases.csv')

# Run the scraping function
df_cases = scrape_page(df)

# Display the DataFrame
print(df_cases)

# Save the DataFrame to a CSV file
df_cases.to_csv('tosdr_cases_with_classification_and_weight.csv', index=False)
# Out:
#                             Case Link Classification Weight
# 0    https://edit.tosdr.org/cases/179            bad     50
# 1    https://edit.tosdr.org/cases/182            bad     50
# 2    https://edit.tosdr.org/cases/183           good     50
# 3    https://edit.tosdr.org/cases/180        neutral     50
# 4    https://edit.tosdr.org/cases/330            bad     50
# ..                                ...            ...    ...
# 255  https://edit.tosdr.org/cases/494           good     10
# 256  https://edit.tosdr.org/cases/228           good     30
# 257  https://edit.tosdr.org/cases/335           good     50
# 258  https://edit.tosdr.org/cases/339            bad     50
# 259  https://edit.tosdr.org/cases/117            bad     50
#
# [260 rows x 3 columns]

# %%
df = pd.read_csv('tosdr_topics_and_cases.csv')
df
# Out:
#                   Topic                        Topic Link  \
# 0             Ownership  https://edit.tosdr.org/topics/27
# 1             Ownership  https://edit.tosdr.org/topics/27
# 2             Ownership  https://edit.tosdr.org/topics/27
# 3             Ownership  https://edit.tosdr.org/topics/27
# 4             Ownership  https://edit.tosdr.org/topics/27
# ..                  ...                               ...
# 255        Transparency  https://edit.tosdr.org/topics/36
# 256        Transparency  https://edit.tosdr.org/topics/36
# 257  Dispute Resolution  https://edit.tosdr.org/topics/42
# 258  Dispute Resolution  https://edit.tosdr.org/topics/42
# 259  Dispute Resolution  https://edit.tosdr.org/topics/42
#
#                                                   Case  \
# 0           This service takes credit for your content
# 1    If you offer suggestions to the service, they ...
# 2               You maintain ownership of your content
# 3    This service can use your content for all thei...
# 4    The service disables software that you are not...
# ..                                                 ...
# 255  An audio version of the Terms of Service is pr...
# 256  Information is provided about what kind of inf...
# 257  You aren’t forced into binding arbitration in ...
# 258  You are forced into binding arbitration in cas...
# 259            You waive your right to a class action.
#
#                             Case Link
# 0    https://edit.tosdr.org/cases/179
# 1    https://edit.tosdr.org/cases/182
# 2    https://edit.tosdr.org/cases/183
# 3    https://edit.tosdr.org/cases/180
# 4    https://edit.tosdr.org/cases/330
# ..                                ...
# 255  https://edit.tosdr.org/cases/494
# 256  https://edit.tosdr.org/cases/228
# 257  https://edit.tosdr.org/cases/335
# 258  https://edit.tosdr.org/cases/339
# 259  https://edit.tosdr.org/cases/117
#
# [260 rows x 4 columns]

# %%
#smaller df to test the following with
df_small_test = df.head()
df_small_test
# Out:
#        Topic                        Topic Link  \
# 0  Ownership  https://edit.tosdr.org/topics/27
# 1  Ownership  https://edit.tosdr.org/topics/27
# 2  Ownership  https://edit.tosdr.org/topics/27
# 3  Ownership  https://edit.tosdr.org/topics/27
# 4  Ownership  https://edit.tosdr.org/topics/27
#
#                                                 Case  \
# 0         This service takes credit for your content
# 1  If you offer suggestions to the service, they ...
# 2             You maintain ownership of your content
# 3  This service can use your content for all thei...
# 4  The service disables software that you are not...
#
#                           Case Link
# 0  https://edit.tosdr.org/cases/179
# 1  https://edit.tosdr.org/cases/182
# 2  https://edit.tosdr.org/cases/183
# 3  https://edit.tosdr.org/cases/180
# 4  https://edit.tosdr.org/cases/330

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random

# Function to scrape 'Service', 'Title', and 'Title Link' for approved rows in a case
def scrape_case_page(case_link):
    response = requests.get(case_link)
    soup = BeautifulSoup(response.content, 'html.parser')

    approved_data = []

    # Loop through the rows in the table
    rows = soup.find_all('tr', {'data-classification': 'bad'})
    for row in rows:
        status = row.find('span', {'class': 'label-success'})

        if status and 'APPROVED' in status.get_text(strip=True):
            service = row.find('th').get_text(strip=True)
            title_tag = row.find('td').find('a')
            title = title_tag.get_text(strip=True)
            title_link = 'https://edit.tosdr.org' + title_tag['href']  # Absolute URL for the title link

            approved_data.append({
                'Case Link': case_link,  # Save Case Link instead of Topic Link
                'Service': service,
                'Title': title,
                'Title Link': title_link
            })

    return approved_data

# Main function to loop through Case Links and scrape the necessary details
def scrape_approved_rows(df):
    all_approved_data = []

    for _, row in df.iterrows():
        case_link = row['Case Link']

        # Scrape the case page for approved entries
        approved_data = scrape_case_page(case_link)
        all_approved_data.extend(approved_data)

        # Add a random sleep between 1 and 3 seconds to avoid getting blocked
        time.sleep(random.uniform(1, 3))

    return pd.DataFrame(all_approved_data)

# Run the scraping function
df_approved = scrape_approved_rows(df)

# Display the resulting DataFrame
print(df_approved)

# Optionally, save to a CSV
df_approved.to_csv('approved_cases.csv', index=False)
# Out:
#                              Case Link                             Service  \
# 0     https://edit.tosdr.org/cases/179                             Earth 2
# 1     https://edit.tosdr.org/cases/179                            JustPark
# 2     https://edit.tosdr.org/cases/179                               Chegg
# 3     https://edit.tosdr.org/cases/179              Chipotle Mexican Grill
# 4     https://edit.tosdr.org/cases/179  Chinese Software Developer Network
# ...                                ...                                 ...
# 7289  https://edit.tosdr.org/cases/117                         GeForce NOW
# 7290  https://edit.tosdr.org/cases/117                              Meower
# 7291  https://edit.tosdr.org/cases/117                        Y Combinator
# 7292  https://edit.tosdr.org/cases/117                               KAYAK
# 7293  https://edit.tosdr.org/cases/117                           HOYOVERSE
#
#                                                   Title  \
# 0     "When you submit material to the Website, you ...
# 1     "By displaying user-generated content on this ...
# 2     "You further agree that Chegg is free to use a...
# 3     "Furthermore, such Submitted Content will fore...
# 4     "用户同意，用户一旦接受本协议，即表明用户同意将其在任何时间在CSDN上传、存储、发表、传播...
# ...                                                 ...
# 7289  "YOU AGREE THAT, BY ENTERING INTO THESE TERMS,...
# 7290            You waive your right to a class action.
# 7291            You waive your right to a class action.
# 7292  "To the extent permitted by law, you agree tha...
# 7293  "Class Action Waiver.\nYou agree that each par...
#
#                                Title Link
# 0     https://edit.tosdr.org/points/23677
# 1     https://edit.tosdr.org/points/26919
# 2     https://edit.tosdr.org/points/32150
# 3     https://edit.tosdr.org/points/33682
# 4     https://edit.tosdr.org/points/15992
# ...                                   ...
# 7289  https://edit.tosdr.org/points/35781
# 7290  https://edit.tosdr.org/points/35884
# 7291  https://edit.tosdr.org/points/36015
# 7292  https://edit.tosdr.org/points/37007
# 7293  https://edit.tosdr.org/points/36318
#
# [7294 rows x 4 columns]

# %%
#loop through the link for each approved annotation, and just grab the name of the document that it comes from
df = pd.read_csv('approved_cases.csv')
df
# Out:
#                              Case Link                             Service  \
# 0     https://edit.tosdr.org/cases/179                             Earth 2
# 1     https://edit.tosdr.org/cases/179                            JustPark
# 2     https://edit.tosdr.org/cases/179                               Chegg
# 3     https://edit.tosdr.org/cases/179              Chipotle Mexican Grill
# 4     https://edit.tosdr.org/cases/179  Chinese Software Developer Network
# ...                                ...                                 ...
# 7289  https://edit.tosdr.org/cases/117                         GeForce NOW
# 7290  https://edit.tosdr.org/cases/117                              Meower
# 7291  https://edit.tosdr.org/cases/117                        Y Combinator
# 7292  https://edit.tosdr.org/cases/117                               KAYAK
# 7293  https://edit.tosdr.org/cases/117                           HOYOVERSE
#
#                                                   Title  \
# 0     "When you submit material to the Website, you ...
# 1     "By displaying user-generated content on this ...
# 2     "You further agree that Chegg is free to use a...
# 3     "Furthermore, such Submitted Content will fore...
# 4     "用户同意，用户一旦接受本协议，即表明用户同意将其在任何时间在CSDN上传、存储、发表、传播...
# ...                                                 ...
# 7289  "YOU AGREE THAT, BY ENTERING INTO THESE TERMS,...
# 7290            You waive your right to a class action.
# 7291            You waive your right to a class action.
# 7292  "To the extent permitted by law, you agree tha...
# 7293  "Class Action Waiver.\nYou agree that each par...
#
#                                Title Link
# 0     https://edit.tosdr.org/points/23677
# 1     https://edit.tosdr.org/points/26919
# 2     https://edit.tosdr.org/points/32150
# 3     https://edit.tosdr.org/points/33682
# 4     https://edit.tosdr.org/points/15992
# ...                                   ...
# 7289  https://edit.tosdr.org/points/35781
# 7290  https://edit.tosdr.org/points/35884
# 7291  https://edit.tosdr.org/points/36015
# 7292  https://edit.tosdr.org/points/37007
# 7293  https://edit.tosdr.org/points/36318
#
# [7294 rows x 4 columns]

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random

# Function to scrape the source document name and link from the Title Link
def scrape_source_from_title_link(title_link):
    response = requests.get(title_link)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find the blockquote, source document name, and link
    blockquote = soup.find('blockquote')
    if blockquote:
        footer = blockquote.find('footer')
        if footer:
            source_tag = footer.find('a')
            if source_tag:
                source_name = source_tag.get_text(strip=True)
                source_link = 'https://edit.tosdr.org' + source_tag['href']  # Add prefix to the source link
                return source_name, source_link

    return None, None

# Main function to loop through Title Links and update with source details
def update_with_source_details(df, save_interval=10):
    updated_data = []

    for i, row in df.iterrows():
        print(f"Processing row {i + 1}/{len(df)}...")  # Print the row number being processed

        title_link = row['Title Link']

        # Scrape the source document name and link
        source_name, source_link = scrape_source_from_title_link(title_link)

        # Add the source details to the existing row
        updated_row = {
            'Case Link': row['Case Link'],
            'Service': row['Service'],
            'Title': row['Title'],
            'Title Link': title_link,
            'Source Name': source_name,
            'Source Link': source_link
        }
        updated_data.append(updated_row)

        # Add a random sleep between 1 and 3 seconds to avoid being blocked
        time.sleep(random.uniform(1, 2))

        # Save progress every 'save_interval' rows
        if (i + 1) % save_interval == 0:
            df_temp = pd.DataFrame(updated_data)
            df_temp.to_csv('updated_cases_with_sources.csv', index=False)
            print(f"Saved progress at row {i + 1}.")

    # Final save when the loop is complete
    df_final = pd.DataFrame(updated_data)
    df_final.to_csv('updated_cases_with_sources.csv', index=False)
    print("Final save completed.")

    return df_final

# Assuming df_approved is the DataFrame already loaded into your Python environment
df_updated = update_with_source_details(df, save_interval=10)

# Display the updated DataFrame with source information
print(df_updated)
# Out:
# Processing row 1/7294...
# Processing row 2/7294...
# Processing row 3/7294...
# Processing row 4/7294...
# Processing row 5/7294...
# Processing row 6/7294...
# Processing row 7/7294...
# Processing row 8/7294...
# Processing row 9/7294...
# Processing row 10/7294...
# Saved progress at row 10.
# Processing row 11/7294...
# Processing row 12/7294...
# Processing row 13/7294...
# Processing row 14/7294...
# Processing row 15/7294...
# Processing row 16/7294...
# Processing row 17/7294...
# Processing row 18/7294...
# Processing row 19/7294...
# Processing row 20/7294...
# Saved progress at row 7290.
# Processing row 7291/7294...
# Processing row 7292/7294...
# Processing row 7293/7294...
# Processing row 7294/7294...
# Final save completed.
#                              Case Link                             Service  \
# 0     https://edit.tosdr.org/cases/179                             Earth 2
# 1     https://edit.tosdr.org/cases/179                            JustPark
# 2     https://edit.tosdr.org/cases/179                               Chegg
# 3     https://edit.tosdr.org/cases/179              Chipotle Mexican Grill
# 4     https://edit.tosdr.org/cases/179  Chinese Software Developer Network
# ...                                ...                                 ...
# 7289  https://edit.tosdr.org/cases/117                         GeForce NOW
# 7290  https://edit.tosdr.org/cases/117                              Meower
# 7291  https://edit.tosdr.org/cases/117                        Y Combinator
# 7292  https://edit.tosdr.org/cases/117                               KAYAK
# 7293  https://edit.tosdr.org/cases/117                           HOYOVERSE
#
#                                                   Title  \
# 0     "When you submit material to the Website, you ...
# 1     "By displaying user-generated content on this ...
# 2     "You further agree that Chegg is free to use a...
# 3     "Furthermore, such Submitted Content will fore...
# 4     "用户同意，用户一旦接受本协议，即表明用户同意将其在任何时间在CSDN上传、存储、发表、传播...
# ...                                                 ...
# 7289  "YOU AGREE THAT, BY ENTERING INTO THESE TERMS,...
# 7290            You waive your right to a class action.
# 7291            You waive your right to a class action.
# 7292  "To the extent permitted by law, you agree tha...
# 7293  "Class Action Waiver.\nYou agree that each par...
#
#                                Title Link           Source Name  \
# 0     https://edit.tosdr.org/points/23677    Terms & Conditions
# 1     https://edit.tosdr.org/points/26919  Terms and Conditions
# 2     https://edit.tosdr.org/points/32150          Terms of Use
# 3     https://edit.tosdr.org/points/33682          TERMS OF USE
# 4     https://edit.tosdr.org/points/15992      Terms of Service
# ...                                   ...                   ...
# 7289  https://edit.tosdr.org/points/35781          Terms of Use
# 7290  https://edit.tosdr.org/points/35884                  None
# 7291  https://edit.tosdr.org/points/36015                  None
# 7292  https://edit.tosdr.org/points/37007    Terms & Conditions
# 7293  https://edit.tosdr.org/points/36318      Terms of Service
#
#                                             Source Link
# 0     https://edit.tosdr.org/services/4470/annotate#...
# 1     https://edit.tosdr.org/services/284/annotate#d...
# 2     https://edit.tosdr.org/services/1950/annotate#...
# 3     https://edit.tosdr.org/services/7063/annotate#...
# 4     https://edit.tosdr.org/services/2734/annotate#...
# ...                                                 ...
# 7289  https://edit.tosdr.org/services/4711/annotate#...
# 7290                                               None
# 7291                                               None
# 7292  https://edit.tosdr.org/services/6266/annotate#...
# 7293  https://edit.tosdr.org/services/9401/annotate#...
#
# [7294 rows x 6 columns]

# %% [markdown]
# ## do all the merges to put all of the csvs created in this doc together.

# %%
df1 = pd.read_csv('tosdr_topics_and_cases.csv')
df2 = pd.read_csv('tosdr_cases_with_classification_and_weight.csv')

#merge on the column Case Link
merged_df = pd.merge(df1, df2, on='Case Link', how='inner')

# %%
merged_df
# Out:
#                   Topic                        Topic Link  \
# 0             Ownership  https://edit.tosdr.org/topics/27
# 1             Ownership  https://edit.tosdr.org/topics/27
# 2             Ownership  https://edit.tosdr.org/topics/27
# 3             Ownership  https://edit.tosdr.org/topics/27
# 4             Ownership  https://edit.tosdr.org/topics/27
# ..                  ...                               ...
# 255        Transparency  https://edit.tosdr.org/topics/36
# 256        Transparency  https://edit.tosdr.org/topics/36
# 257  Dispute Resolution  https://edit.tosdr.org/topics/42
# 258  Dispute Resolution  https://edit.tosdr.org/topics/42
# 259  Dispute Resolution  https://edit.tosdr.org/topics/42
#
#                                                   Case  \
# 0           This service takes credit for your content
# 1    If you offer suggestions to the service, they ...
# 2               You maintain ownership of your content
# 3    This service can use your content for all thei...
# 4    The service disables software that you are not...
# ..                                                 ...
# 255  An audio version of the Terms of Service is pr...
# 256  Information is provided about what kind of inf...
# 257  You aren’t forced into binding arbitration in ...
# 258  You are forced into binding arbitration in cas...
# 259            You waive your right to a class action.
#
#                             Case Link Classification  Weight
# 0    https://edit.tosdr.org/cases/179            bad    50.0
# 1    https://edit.tosdr.org/cases/182            bad    50.0
# 2    https://edit.tosdr.org/cases/183           good    50.0
# 3    https://edit.tosdr.org/cases/180        neutral    50.0
# 4    https://edit.tosdr.org/cases/330            bad    50.0
# ..                                ...            ...     ...
# 255  https://edit.tosdr.org/cases/494           good    10.0
# 256  https://edit.tosdr.org/cases/228           good    30.0
# 257  https://edit.tosdr.org/cases/335           good    50.0
# 258  https://edit.tosdr.org/cases/339            bad    50.0
# 259  https://edit.tosdr.org/cases/117            bad    50.0
#
# [260 rows x 6 columns]

# %%
df3 = pd.read_csv('updated_cases_with_sources.csv')
df3
# Out:
#                              Case Link                             Service  \
# 0     https://edit.tosdr.org/cases/179                             Earth 2
# 1     https://edit.tosdr.org/cases/179                            JustPark
# 2     https://edit.tosdr.org/cases/179                               Chegg
# 3     https://edit.tosdr.org/cases/179              Chipotle Mexican Grill
# 4     https://edit.tosdr.org/cases/179  Chinese Software Developer Network
# ...                                ...                                 ...
# 7289  https://edit.tosdr.org/cases/117                         GeForce NOW
# 7290  https://edit.tosdr.org/cases/117                              Meower
# 7291  https://edit.tosdr.org/cases/117                        Y Combinator
# 7292  https://edit.tosdr.org/cases/117                               KAYAK
# 7293  https://edit.tosdr.org/cases/117                           HOYOVERSE
#
#                                                   Title  \
# 0     "When you submit material to the Website, you ...
# 1     "By displaying user-generated content on this ...
# 2     "You further agree that Chegg is free to use a...
# 3     "Furthermore, such Submitted Content will fore...
# 4     "用户同意，用户一旦接受本协议，即表明用户同意将其在任何时间在CSDN上传、存储、发表、传播...
# ...                                                 ...
# 7289  "YOU AGREE THAT, BY ENTERING INTO THESE TERMS,...
# 7290            You waive your right to a class action.
# 7291            You waive your right to a class action.
# 7292  "To the extent permitted by law, you agree tha...
# 7293  "Class Action Waiver.\nYou agree that each par...
#
#                                Title Link           Source Name  \
# 0     https://edit.tosdr.org/points/23677    Terms & Conditions
# 1     https://edit.tosdr.org/points/26919  Terms and Conditions
# 2     https://edit.tosdr.org/points/32150          Terms of Use
# 3     https://edit.tosdr.org/points/33682          TERMS OF USE
# 4     https://edit.tosdr.org/points/15992      Terms of Service
# ...                                   ...                   ...
# 7289  https://edit.tosdr.org/points/35781          Terms of Use
# 7290  https://edit.tosdr.org/points/35884                   NaN
# 7291  https://edit.tosdr.org/points/36015                   NaN
# 7292  https://edit.tosdr.org/points/37007    Terms & Conditions
# 7293  https://edit.tosdr.org/points/36318      Terms of Service
#
#                                             Source Link
# 0     https://edit.tosdr.org/services/4470/annotate#...
# 1     https://edit.tosdr.org/services/284/annotate#d...
# 2     https://edit.tosdr.org/services/1950/annotate#...
# 3     https://edit.tosdr.org/services/7063/annotate#...
# 4     https://edit.tosdr.org/services/2734/annotate#...
# ...                                                 ...
# 7289  https://edit.tosdr.org/services/4711/annotate#...
# 7290                                                NaN
# 7291                                                NaN
# 7292  https://edit.tosdr.org/services/6266/annotate#...
# 7293  https://edit.tosdr.org/services/9401/annotate#...
#
# [7294 rows x 6 columns]

# %%
# Perform a left merge to retain all rows from df3
final_df = pd.merge(merged_df, df3, on='Case Link', how='right')
final_df
# Out:
#                    Topic                        Topic Link  \
# 0              Ownership  https://edit.tosdr.org/topics/27
# 1              Ownership  https://edit.tosdr.org/topics/27
# 2              Ownership  https://edit.tosdr.org/topics/27
# 3              Ownership  https://edit.tosdr.org/topics/27
# 4              Ownership  https://edit.tosdr.org/topics/27
# ...                  ...                               ...
# 7289  Dispute Resolution  https://edit.tosdr.org/topics/42
# 7290  Dispute Resolution  https://edit.tosdr.org/topics/42
# 7291  Dispute Resolution  https://edit.tosdr.org/topics/42
# 7292  Dispute Resolution  https://edit.tosdr.org/topics/42
# 7293  Dispute Resolution  https://edit.tosdr.org/topics/42
#
#                                             Case  \
# 0     This service takes credit for your content
# 1     This service takes credit for your content
# 2     This service takes credit for your content
# 3     This service takes credit for your content
# 4     This service takes credit for your content
# ...                                          ...
# 7289     You waive your right to a class action.
# 7290     You waive your right to a class action.
# 7291     You waive your right to a class action.
# 7292     You waive your right to a class action.
# 7293     You waive your right to a class action.
#
#                              Case Link Classification  Weight  \
# 0     https://edit.tosdr.org/cases/179            bad    50.0
# 1     https://edit.tosdr.org/cases/179            bad    50.0
# 2     https://edit.tosdr.org/cases/179            bad    50.0
# 3     https://edit.tosdr.org/cases/179            bad    50.0
# 4     https://edit.tosdr.org/cases/179            bad    50.0
# ...                                ...            ...     ...
# 7289  https://edit.tosdr.org/cases/117            bad    50.0
# 7290  https://edit.tosdr.org/cases/117            bad    50.0
# 7291  https://edit.tosdr.org/cases/117            bad    50.0
# 7292  https://edit.tosdr.org/cases/117            bad    50.0
# 7293  https://edit.tosdr.org/cases/117            bad    50.0
#
#                                  Service  \
# 0                                Earth 2
# 1                               JustPark
# 2                                  Chegg
# 3                 Chipotle Mexican Grill
# 4     Chinese Software Developer Network
# ...                                  ...
# 7289                         GeForce NOW
# 7290                              Meower
# 7291                        Y Combinator
# 7292                               KAYAK
# 7293                           HOYOVERSE
#
#                                                   Title  \
# 0     "When you submit material to the Website, you ...
# 1     "By displaying user-generated content on this ...
# 2     "You further agree that Chegg is free to use a...
# 3     "Furthermore, such Submitted Content will fore...
# 4     "用户同意，用户一旦接受本协议，即表明用户同意将其在任何时间在CSDN上传、存储、发表、传播...
# ...                                                 ...
# 7289  "YOU AGREE THAT, BY ENTERING INTO THESE TERMS,...
# 7290            You waive your right to a class action.
# 7291            You waive your right to a class action.
# 7292  "To the extent permitted by law, you agree tha...
# 7293  "Class Action Waiver.\nYou agree that each par...
#
#                                Title Link           Source Name  \
# 0     https://edit.tosdr.org/points/23677    Terms & Conditions
# 1     https://edit.tosdr.org/points/26919  Terms and Conditions
# 2     https://edit.tosdr.org/points/32150          Terms of Use
# 3     https://edit.tosdr.org/points/33682          TERMS OF USE
# 4     https://edit.tosdr.org/points/15992      Terms of Service
# ...                                   ...                   ...
# 7289  https://edit.tosdr.org/points/35781          Terms of Use
# 7290  https://edit.tosdr.org/points/35884                   NaN
# 7291  https://edit.tosdr.org/points/36015                   NaN
# 7292  https://edit.tosdr.org/points/37007    Terms & Conditions
# 7293  https://edit.tosdr.org/points/36318      Terms of Service
#
#                                             Source Link
# 0     https://edit.tosdr.org/services/4470/annotate#...
# 1     https://edit.tosdr.org/services/284/annotate#d...
# 2     https://edit.tosdr.org/services/1950/annotate#...
# 3     https://edit.tosdr.org/services/7063/annotate#...
# 4     https://edit.tosdr.org/services/2734/annotate#...
# ...                                                 ...
# 7289  https://edit.tosdr.org/services/4711/annotate#...
# 7290                                                NaN
# 7291                                                NaN
# 7292  https://edit.tosdr.org/services/6266/annotate#...
# 7293  https://edit.tosdr.org/services/9401/annotate#...
#
# [7294 rows x 11 columns]

# %%
#merge in the ratings
df4 = pd.read_csv('services_and_ratings.csv')
df4
# Out:
#        Unnamed: 0               Service Rating
# 0               0            AliExpress      D
# 1               1       Mercatus Center    NaN
# 2               2                MySudo      B
# 3               3              Rec Room      D
# 4               4                Fembed    NaN
# ...           ...                   ...    ...
# 10353       10353        DEPRECATED #63    NaN
# 10354       10354  Wizards of the Coast      C
# 10355       10355     ubergeekstore.com    NaN
# 10356       10356              Visiplex    NaN
# 10357       10357                  IACP    NaN
#
# [10358 rows x 3 columns]

# %%
extra_final_df = pd.merge(final_df, df4[['Service', 'Rating']], on='Service', how='left')
extra_final_df
# Out:
#                    Topic                        Topic Link  \
# 0              Ownership  https://edit.tosdr.org/topics/27
# 1              Ownership  https://edit.tosdr.org/topics/27
# 2              Ownership  https://edit.tosdr.org/topics/27
# 3              Ownership  https://edit.tosdr.org/topics/27
# 4              Ownership  https://edit.tosdr.org/topics/27
# ...                  ...                               ...
# 7291  Dispute Resolution  https://edit.tosdr.org/topics/42
# 7292  Dispute Resolution  https://edit.tosdr.org/topics/42
# 7293  Dispute Resolution  https://edit.tosdr.org/topics/42
# 7294  Dispute Resolution  https://edit.tosdr.org/topics/42
# 7295  Dispute Resolution  https://edit.tosdr.org/topics/42
#
#                                             Case  \
# 0     This service takes credit for your content
# 1     This service takes credit for your content
# 2     This service takes credit for your content
# 3     This service takes credit for your content
# 4     This service takes credit for your content
# ...                                          ...
# 7291     You waive your right to a class action.
# 7292     You waive your right to a class action.
# 7293     You waive your right to a class action.
# 7294     You waive your right to a class action.
# 7295     You waive your right to a class action.
#
#                              Case Link Classification  Weight  \
# 0     https://edit.tosdr.org/cases/179            bad    50.0
# 1     https://edit.tosdr.org/cases/179            bad    50.0
# 2     https://edit.tosdr.org/cases/179            bad    50.0
# 3     https://edit.tosdr.org/cases/179            bad    50.0
# 4     https://edit.tosdr.org/cases/179            bad    50.0
# ...                                ...            ...     ...
# 7291  https://edit.tosdr.org/cases/117            bad    50.0
# 7292  https://edit.tosdr.org/cases/117            bad    50.0
# 7293  https://edit.tosdr.org/cases/117            bad    50.0
# 7294  https://edit.tosdr.org/cases/117            bad    50.0
# 7295  https://edit.tosdr.org/cases/117            bad    50.0
#
#                                  Service  \
# 0                                Earth 2
# 1                               JustPark
# 2                                  Chegg
# 3                 Chipotle Mexican Grill
# 4     Chinese Software Developer Network
# ...                                  ...
# 7291                         GeForce NOW
# 7292                              Meower
# 7293                        Y Combinator
# 7294                               KAYAK
# 7295                           HOYOVERSE
#
#                                                   Title  \
# 0     "When you submit material to the Website, you ...
# 1     "By displaying user-generated content on this ...
# 2     "You further agree that Chegg is free to use a...
# 3     "Furthermore, such Submitted Content will fore...
# 4     "用户同意，用户一旦接受本协议，即表明用户同意将其在任何时间在CSDN上传、存储、发表、传播...
# ...                                                 ...
# 7291  "YOU AGREE THAT, BY ENTERING INTO THESE TERMS,...
# 7292            You waive your right to a class action.
# 7293            You waive your right to a class action.
# 7294  "To the extent permitted by law, you agree tha...
# 7295  "Class Action Waiver.\nYou agree that each par...
#
#                                Title Link           Source Name  \
# 0     https://edit.tosdr.org/points/23677    Terms & Conditions
# 1     https://edit.tosdr.org/points/26919  Terms and Conditions
# 2     https://edit.tosdr.org/points/32150          Terms of Use
# 3     https://edit.tosdr.org/points/33682          TERMS OF USE
# 4     https://edit.tosdr.org/points/15992      Terms of Service
# ...                                   ...                   ...
# 7291  https://edit.tosdr.org/points/35781          Terms of Use
# 7292  https://edit.tosdr.org/points/35884                   NaN
# 7293  https://edit.tosdr.org/points/36015                   NaN
# 7294  https://edit.tosdr.org/points/37007    Terms & Conditions
# 7295  https://edit.tosdr.org/points/36318      Terms of Service
#
#                                             Source Link Rating
# 0     https://edit.tosdr.org/services/4470/annotate#...      D
# 1     https://edit.tosdr.org/services/284/annotate#d...      D
# 2     https://edit.tosdr.org/services/1950/annotate#...      E
# 3     https://edit.tosdr.org/services/7063/annotate#...      D
# 4     https://edit.tosdr.org/services/2734/annotate#...      D
# ...                                                 ...    ...
# 7291  https://edit.tosdr.org/services/4711/annotate#...      D
# 7292                                                NaN      B
# 7293                                                NaN      D
# 7294  https://edit.tosdr.org/services/6266/annotate#...    NaN
# 7295  https://edit.tosdr.org/services/9401/annotate#...    NaN
#
# [7296 rows x 12 columns]

# %%
extra_final_df.to_csv('final_output.csv', index=False)

# %%
#next step is to figure out pattern in why some annotations don't get picked up. but merge things into a more understandable document first.
